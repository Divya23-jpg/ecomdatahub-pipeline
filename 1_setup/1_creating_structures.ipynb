# %% [markdown]
# ###Create Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecommerce;

# %% [markdown]
# ###Use Catalog

# %%
# %sql
USE CATALOG ecommerce;

# %% [markdown]
# ###Creating Schemas in Catalog

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce.bronze;
CREATE SCHEMA IF NOT EXISTS ecommerce.silver;
CREATE SCHEMA IF NOT EXISTS ecommerce.gold;

# %% [markdown]
# ###For Showing DataBases in the catalog named "ecommerce"

# %%
# %sql
SHOW DATABASES FROM ecommerce;

# %% [markdown]
# ###For Dropping All Schmemas and Tables from the catalog

# %%
# We will never run here because we dont want to delete all

# %sql
# -- DROP CATALOG IF EXISTS ecommerce CASCADE;
